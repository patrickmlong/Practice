# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ratings = pd.read_csv('http://bit.ly/imdbratings')

# %%
ratings.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
ratings.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
ratings.describe(include = ['object'])
# Out:
#                                   title content_rating  genre  \
# count                               979            976    979
# unique                              975             12     16
# top     The Girl with the Dragon Tattoo              R  Drama
# freq                                  2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
ratings.describe()#include = ['object'])
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
ratings.describe() # hit shift tab in parenthesis to see all available arguments. 
# Hit multiple times to see more.
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
ratings.rename(columns = {'duration':'Duration', 'actors_list': 'Actors', 'star_rating':'Stars'}, inplace = True)

# %%
ratings.head()
# Out:
#    Stars                     title content_rating   genre  Duration  \
# 0    9.3  The Shawshank Redemption              R   Crime       142
# 1    9.2             The Godfather              R   Crime       175
# 2    9.1    The Godfather: Part II              R   Crime       200
# 3    9.0           The Dark Knight          PG-13  Action       152
# 4    8.9              Pulp Fiction              R   Crime       154
#
#                                               Actors
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
ratings2 = ratings[ratings['Duration'] > 100]
# Out:
#      Stars                                              title content_rating  \
# 0      9.3                           The Shawshank Redemption              R
# 1      9.2                                      The Godfather              R
# 2      9.1                             The Godfather: Part II              R
# 3      9.0                                    The Dark Knight          PG-13
# 4      8.9                                       Pulp Fiction              R
# 6      8.9                     The Good, the Bad and the Ugly      NOT RATED
# 7      8.9      The Lord of the Rings: The Return of the King          PG-13
# 8      8.9                                   Schindler's List              R
# 9      8.9                                         Fight Club              R
# 10     8.8  The Lord of the Rings: The Fellowship of the Ring          PG-13
# 11     8.8                                          Inception          PG-13
# ...

# %%
sns.boxplot(x = ratings.iloc[:20, 3], y = 'Duration', data = ratings)
plt.show()

# %%
ratings[ratings['Stars'] > 8].genre
# Out:
# 0          Crime
# 1          Crime
# 2          Crime
# 3         Action
# 4          Crime
# 5          Drama
# 6        Western
# 7      Adventure
# 8      Biography
# 9          Drama
# 10     Adventure
# 11        Action
# 12        Action
# 13         Drama
# 14     Adventure
# 15     Adventure
# 16         Drama
# 17         Drama
# 18     Biography
# 19        Action
# 20        Action
# 21         Crime
# 22         Drama
# 23         Crime
# 24         Drama
# 25        Comedy
# 26       Western
# 27         Drama
# 28         Crime
# 29        Comedy
#          ...
# 267        Drama
# 268       Action
# 269        Drama
# 270        Drama
# 271    Adventure
# 272        Crime
# 273    Biography
# 274    Biography
# 275       Comedy
# 276       Action
# 277    Animation
# 278        Crime
# 279        Drama
# 280       Comedy
# 281       Action
# 282       Comedy
# 283        Drama
# 284        Drama
# 285       Comedy
# 286    Biography
# 287       Comedy
# ...

# %%
ratings.genre.astype('category')
# Out:
# 0          Crime
# 1          Crime
# 2          Crime
# 3         Action
# 4          Crime
# 5          Drama
# 6        Western
# 7      Adventure
# 8      Biography
# 9          Drama
# 10     Adventure
# 11        Action
# 12        Action
# 13         Drama
# 14     Adventure
# 15     Adventure
# 16         Drama
# 17         Drama
# 18     Biography
# 19        Action
# 20        Action
# 21         Crime
# 22         Drama
# 23         Crime
# 24         Drama
# 25        Comedy
# 26       Western
# 27         Drama
# 28         Crime
# 29        Comedy
#          ...
# 949       Comedy
# 950        Crime
# 951        Drama
# 952       Comedy
# 953    Adventure
# 954       Action
# 955        Drama
# 956       Comedy
# 957       Comedy
# 958        Drama
# 959       Comedy
# 960       Comedy
# 961    Biography
# 962       Comedy
# 963       Action
# 964    Biography
# 965      Mystery
# 966    Animation
# 967       Action
# 968        Drama
# 969        Crime
# ...

# %%
ratings.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
c = ratings[ratings['genre'] == 'Crime']

# %%
c.title.value_counts()
# Out:
# The Girl with the Dragon Tattoo    2
# This Is England                    1
# Badlands                           1
# The Counterfeiters                 1
# The 400 Blows                      1
# Leon: The Professional             1
# The Town                           1
# I Saw the Devil                    1
# American History X                 1
# Taxi Driver                        1
# The Night of the Hunter            1
# 21 Grams                           1
# Carlito's Way                      1
# The Maltese Falcon                 1
# Sympathy for Mr. Vengeance         1
# L.A. Confidential                  1
# Inside Man                         1
# Gangs of New York                  1
# Miller's Crossing                  1
# Maria Full of Grace                1
# Collateral                         1
# Le Samourai                        1
# Ocean's Eleven                     1
# Funny Games                        1
# American Psycho                    1
# ...
